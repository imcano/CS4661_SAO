# %% [markdown]
# # CS4661 (Intro to Data Science) - Shelter Animal Outcomes
# # Author: Group #3
# ## Dataset: https://www.kaggle.com/c/shelter-animal-outcomes

# %%
"""
Preprocesses the shelter-animal-outcomes (sao) dataset

Parameters:

Returns:

"""
# Out:
# '\nPreprocesses the shelter-animal-outcomes (sao) dataset\n\nParameters:\n\nReturns:\n\n'

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Reading the sao dataset

# %%
df = pd.read_csv('../../data/train.csv') # stores the sao testing dataset 
df[:10] # displays first 10 rows
# Out:
#    ID        Name             DateTime AnimalType SexuponOutcome  \
# 0   1      Summer  2015-10-12 12:15:00        Dog  Intact Female
# 1   2    Cheyenne  2014-07-26 17:59:00        Dog  Spayed Female
# 2   3         Gus  2016-01-13 12:20:00        Cat  Neutered Male
# 3   4       Pongo  2013-12-28 18:12:00        Dog    Intact Male
# 4   5     Skooter  2015-09-24 17:59:00        Dog  Neutered Male
# 5   6        Beau  2015-06-23 11:17:00        Dog  Neutered Male
# 6   7        Bobo  2014-03-12 09:45:00        Cat  Neutered Male
# 7   8        Abby  2014-06-25 08:27:00        Cat  Spayed Female
# 8   9  Ruby Grace  2014-11-12 18:05:00        Dog  Spayed Female
# 9  10        Ruby  2014-04-07 17:41:00        Dog  Spayed Female
#
#   AgeuponOutcome                           Breed              Color
# 0      10 months          Labrador Retriever Mix          Red/White
# 1        2 years  German Shepherd/Siberian Husky          Black/Tan
# 2         1 year          Domestic Shorthair Mix        Brown Tabby
# 3       4 months               Collie Smooth Mix           Tricolor
# 4        2 years            Miniature Poodle Mix              White
# 5        3 years                      Beagle Mix        Brown/White
# 6       13 years        Domestic Medium Hair Mix  Brown Tabby/White
# 7       6 months          Domestic Shorthair Mix        Brown Tabby
# 8       3 months                   Cairn Terrier        Black/Cream
# 9         1 year                    Pit Bull Mix        Brown/White

# %%
feature_cols = list(df.columns) # stores each column name in a list
feature_cols # displays all column headers
# Out:
# ['ID',
#  'Name',
#  'DateTime',
#  'AnimalType',
#  'SexuponOutcome',
#  'AgeuponOutcome',
#  'Breed',
#  'Color']

# %%
junk_cols = ['ID', 'Name', 'DateTime'] # useless columns
df = df.drop(junk_cols, axis=1) # drop the junk cols from the dataset
df[:10] # displays first 10 rows of changed df
# Out:
#   AnimalType SexuponOutcome AgeuponOutcome                           Breed  \
# 0        Dog  Intact Female      10 months          Labrador Retriever Mix
# 1        Dog  Spayed Female        2 years  German Shepherd/Siberian Husky
# 2        Cat  Neutered Male         1 year          Domestic Shorthair Mix
# 3        Dog    Intact Male       4 months               Collie Smooth Mix
# 4        Dog  Neutered Male        2 years            Miniature Poodle Mix
# 5        Dog  Neutered Male        3 years                      Beagle Mix
# 6        Cat  Neutered Male       13 years        Domestic Medium Hair Mix
# 7        Cat  Spayed Female       6 months          Domestic Shorthair Mix
# 8        Dog  Spayed Female       3 months                   Cairn Terrier
# 9        Dog  Spayed Female         1 year                    Pit Bull Mix
#
#                Color
# 0          Red/White
# 1          Black/Tan
# 2        Brown Tabby
# 3           Tricolor
# 4              White
# 5        Brown/White
# 6  Brown Tabby/White
# 7        Brown Tabby
# 8        Black/Cream
# 9        Brown/White

# %%
colors = [c.replace(' ', '/') for c in list(df.Color)] # replace all spaces in Color with '/'
colors[:5] # displays first 5 rows of colors
# Out:
# [['Red', 'White'],
#  ['Black', 'Tan'],
#  ['Brown', 'Tabby'],
#  ['Tricolor'],
#  ['White']]
