# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('../../data/train_V2.csv')

# %%
df[:10]
# Out:
#    Unnamed: 0      OutcomeType  Cat  Dog  Female  Intact  Male  Neutered  \
# 0           0  Return_to_owner    0    1       0       0     1         1
# 1           1       Euthanasia    1    0       1       0     0         0
# 2           2         Adoption    0    1       0       0     1         1
# 3           3         Transfer    1    0       0       1     1         0
# 4           4         Transfer    0    1       0       0     1         1
# 5           5         Transfer    0    1       1       1     0         0
# 6           6         Transfer    1    0       0       1     1         0
# 7           7         Transfer    1    0       0       0     0         0
# 8           8         Adoption    0    1       1       0     0         0
# 9           9         Adoption    0    1       1       0     0         0
#
#    Spayed  Age    ...     Tan  Tick  Tiger  Torbie  Tortie  Tricolor  White  \
# 0       0  365    ...       0     0      0       0       0         0      1
# 1       1  365    ...       0     0      0       0       0         0      0
# 2       0  730    ...       0     0      0       0       0         0      1
# 3       0   21    ...       0     0      0       0       0         0      0
# 4       0  730    ...       1     0      0       0       0         0      0
# 5       0   30    ...       1     0      0       0       0         0      0
# 6       0   21    ...       0     0      0       0       0         0      0
# 7       0   21    ...       0     0      0       0       0         0      0
# 8       1  150    ...       0     0      0       0       0         0      1
# 9       1  365    ...       0     0      0       0       0         0      1
#
#    Yellow  Mixed  Purebred
# 0       0      1         0
# 1       0      1         0
# 2       0      1         0
# 3       0      1         0
# 4       0      0         1
# 5       0      0         1
# 6       0      1         0
# 7       0      1         0
# 8       0      1         0
# 9       0      0         1
#
# [10 rows x 48 columns]

# %%
feature_cols = ['Cat','Dog','Female','Intact','Male','Neutered','Spayed','Age','Tan','Tick','Tiger','Torbie','Tricolor','White','Yellow','Mixed','Purebred']

X = df[feature_cols]

# %%
y = df['OutcomeType']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
k = 24
my_knn = KNeighborsClassifier(n_neighbors=k)
my_knn.fit(X_train, y_train)
y_predict = my_knn.predict(X_test)
accuracy = accuracy_score(y_test, y_predict)

print(accuracy)
# Out:
# 0.6219603441825664

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
